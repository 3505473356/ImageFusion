# %%
import torch
from torch.nn.functional import conv2d, softmax
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %%
def correlation(image, edge_L, edge_R, isInfrared=False):
    
    img = cv2.cvtColor(cv2.imread(image),cv2.COLOR_BGR2RGB)
    print("Image shape: H:{}, W:{}, C:{}".format(img.shape[0], img.shape[1], img.shape[2]))
    
    if isInfrared:
        img = img[:,:,1].reshape(img.shape[0], img.shape[1], 1)
        
        print("Infrared process: H:{}, W:{}, C:{}".format(img.shape[0], img.shape[1], img.shape[2]))
        
    cut_out = img[:, edge_L:edge_R, :]
    cut_out_length = edge_R - edge_L
    print("CutOut shape: H:{}, W:{}, C:{}".format(cut_out.shape[0], cut_out.shape[1], cut_out.shape[2]))
    print("Length:{}".format(cut_out_length))
    
    img_Tensor = torch.from_numpy(img.reshape(1,img.shape[2],img.shape[0],img.shape[1]))
    cut_out_Tensor = torch.from_numpy(cut_out.reshape(1,cut_out.shape[2],cut_out.shape[0],cut_out.shape[1]))
    
    match_map = conv2d(img_Tensor, cut_out_Tensor)
    prob = softmax(match_map.view(-1,1).float(), dim = 0)
    prob = prob.numpy()
    
    displacement = np.arange(0, img.shape[1] - cut_out_length+1) - edge_L
    
    abs_error = prob.argmax() - edge_L
    peaks = np.where(prob > prob.max()*0.85)[0] - edge_L
    num_peaks = len(peaks)
    
    plt.figure("output", figsize = (4,8))
    plt.subplot(2,1,1)
    plt.imshow(img)
    plt.subplot(2,1,2)
    plt.imshow(cut_out)
    plt.figure(figsize = (8,4))
    plt.plot(displacement, prob)
    plt.title("Output of correlation")
    plt.xlabel("displacement")
    plt.ylabel("probability")
    plt.show()
    
    return abs_error, num_peaks, match_map, prob, displacement

def log_fusion(prob_ir, prob_rgb, displacement, edge_L):
    fusion_result =  prob_ir * prob_rgb
    print("Shape of ir_result: {}".format(prob_ir.shape))
    print("Shape of rgb_result: {}".format(prob_rgb.shape))
    print("Shape of fusion_result: {}".format(fusion_result.shape))
    
    abs_error = fusion_result.argmax() - edge_L
    peaks = np.where(fusion_result > fusion_result.max()*0.6)[0] - edge_L
    num_peaks = len(peaks)
    
    print("{} peaks, location: {}".format(num_peaks,peaks))
    print("Absolute error: {}".format(abs_error))
    
    plt.figure("fusion_output", figsize = (8,4))
    plt.title("Output of fusion")
    plt.xlabel("displacement")
    plt.ylabel("probability")
    plt.plot(displacement, fusion_result)
    
    return abs_error, peaks, num_peaks

def abs_fusion(cor_value_ir, cor_value_rgb, displacement, edge_L):
    abs_result =  cor_value_rgb * cor_value_ir
#     abs_result_tensor = torch.from_numpy(abs_result)
    
    prob = softmax(abs_result.view(-1,1).float(), dim = 0)
    prob = prob.numpy()
    
    abs_error = prob.argmax() - edge_L
    peaks = np.where(prob > prob.max()*0.6)[0] - edge_L
    num_peaks = len(peaks)
    
    print("{} peaks, location: {}".format(len(peaks),peaks))
    print("Absolute error: {}".format(abs_error))
    
    plt.figure("fusion_output", figsize = (8,4))
    plt.plot(displacement,prob)
    
    return abs_error, peaks, num_peaks

# %% [markdown]
# ## One cutout in one pair image

# %%
_, _,cor_ir, prob_ir, dis = correlation("video7_ir.png", 200, 400, True)
# Out:
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200

# %%
_, _,cor_rgb, prob_rgb, dis = correlation("video7_rgb.png", 200, 400, False)
# Out:
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200

# %%
log_fusion(prob_ir, prob_rgb, dis, 200)
# Out:
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [7]
# Absolute error: 7
# (7, array([7], dtype=int64), 1)

# %%
abs_fusion(cor_ir, cor_rgb, dis, 200)
# Out:
# 1 peaks, location: [99]
# Absolute error: 99
# (99, array([99], dtype=int64), 1)

# %% [markdown]
# ## Multi-cutout in multi-pair images

# %%
root = "vid04/"
root_ir = "vid04/lwir/"
root_rgb = "vid04/rgb/"

ir_img_list = os.listdir(root_ir) 
rgb_img_list = os.listdir(root_rgb)

result_fold = [root + "result_ir", root + "result_rgb", root + "result_fusion"]

for folder in result_fold:
    isExist = os.path.exists(folder)
    
    if not isExist:
        os.makedirs(folder)
        print(folder + " is created.")
        
    else:
        print(folder + " is existed.")
# Out:
# vid04/result_ir is existed.
# vid04/result_rgb is existed.
# vid04/result_fusion is existed.

# %%
rgb_img_list = rgb_img_list[:6]
print(rgb_img_list)

ir_img_list = rgb_img_list[:6]
print(ir_img_list)
# Out:
# ['00498.png', '00508.png', '00510.png', '00515.png', '00524.png', '00534.png']
# ['00498.png', '00508.png', '00510.png', '00515.png', '00524.png', '00534.png']

# %%
err_fusion_solo = []
err_ir_solo = []
err_rgb_solo = []
num_peaks_solo = []

err_ir_mul = []
err_rgb_mul = []
err_fusion_mul = []

length = 200

for ir_img, rgb_img in zip(ir_img_list, rgb_img_list):
    for i in range(150, 400, 10):
        edge_L = i
        edge_R = i + length
        
        err_ir, num_peaks_ir, match_map_ir, prob_ir, displacement = correlation(root_ir+ir_img, edge_L, edge_R, True)
        err_rgb, num_peaks_rgb, match_map_rgb, prob_rgb, displacement = correlation(root_rgb+rgb_img, edge_L, edge_R, False)

        abs_error, peaks, num_peaks = log_fusion(prob_ir, prob_rgb, displacement, edge_L)
        
        num_peaks_solo.append(num_peaks)
        err_fusion_solo.append(abs_error)
        err_ir_solo.append(err_ir)
        err_rgb_solo.append(err_rgb)
        
    err_ir_mul.append(np.absolute(err_ir_solo).mean())
    err_rgb_mul.append(np.absolute(err_rgb_solo).mean())
    err_fusion_mul.append(np.absolute(err_fusion_solo).mean())
    
    np.save(result_fold[0] + "/" + str(ir_img) + ".npy", np.array(err_ir_solo))
    np.save(result_fold[1] + "/" + str(rgb_img) + ".npy", np.array(err_rgb_solo))
    np.save(result_fold[2] + "/" + str(ir_img) + ".npy", np.array(err_fusion_solo))
    
    err_fusion_solo = []
    err_ir_solo = []
    err_rgb_solo = []
    
err_ir_mul = np.array(err_ir_mul).reshape(-1,1)
err_rgb_mul = np.array(err_rgb_mul).reshape(-1,1)
err_fusion_mul = np.array(err_fusion_mul).reshape(-1,1)

np.save(result_fold[0] + "/" + "ir_all_imgs.npy", np.array(err_ir_mul))
np.save(result_fold[1] + "/" + "rgb_all_imgs.npy", np.array(err_rgb_mul))
np.save(result_fold[2] + "/" + "fusion_all_imgs.npy", np.array(err_fusion_mul))
# Out:
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [16]
# Absolute error: 16
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [130]
# Absolute error: 130
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-80]
# Absolute error: -80
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-103]
# Absolute error: -103
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [118]
# Absolute error: 118
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [176]
# Absolute error: 176
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [94]
# Absolute error: 94
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [133]
# Absolute error: 133
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-93]
# Absolute error: -93
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [11]
# Absolute error: 11
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [46]
# Absolute error: 46
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [26]
# Absolute error: 26
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-122]
# Absolute error: -122
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [145]
# Absolute error: 145
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-219]
# Absolute error: -219
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-87]
# Absolute error: -87
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-275]
# Absolute error: -275
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-270]
# Absolute error: -270
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-309]
# Absolute error: -309
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [3]
# Absolute error: 3
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-66]
# Absolute error: -66
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-258]
# Absolute error: -258
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-3]
# Absolute error: -3
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-310]
# Absolute error: -310
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-161]
# Absolute error: -161
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [134]
# Absolute error: 134
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-94]
# Absolute error: -94
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 2 peaks, location: [-147   13]
# Absolute error: -147
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [75]
# Absolute error: 75
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [75]
# Absolute error: 75
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [199]
# Absolute error: 199
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [10]
# Absolute error: 10
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [180]
# Absolute error: 180
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [196]
# Absolute error: 196
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 2 peaks, location: [-181  199]
# Absolute error: -181
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-151]
# Absolute error: -151
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-63]
# Absolute error: -63
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-147]
# Absolute error: -147
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-193]
# Absolute error: -193
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-121]
# Absolute error: -121
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-229]
# Absolute error: -229
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-52]
# Absolute error: -52
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-112]
# Absolute error: -112
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-78]
# Absolute error: -78
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [7]
# Absolute error: 7
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-281]
# Absolute error: -281
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-84]
# Absolute error: -84
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-38]
# Absolute error: -38
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-226]
# Absolute error: -226
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 2 peaks, location: [-120  -18]
# Absolute error: -120
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [55]
# Absolute error: 55
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-104]
# Absolute error: -104
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-42]
# Absolute error: -42
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [45]
# Absolute error: 45
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [77]
# Absolute error: 77
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [202]
# Absolute error: 202
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [58]
# Absolute error: 58
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [143]
# Absolute error: 143
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-63]
# Absolute error: -63
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-236]
# Absolute error: -236
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-195]
# Absolute error: -195
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-119]
# Absolute error: -119
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [61]
# Absolute error: 61
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [43]
# Absolute error: 43
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-267]
# Absolute error: -267
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-62]
# Absolute error: -62
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-295]
# Absolute error: -295
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-9]
# Absolute error: -9
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-166]
# Absolute error: -166
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [78]
# Absolute error: 78
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-170]
# Absolute error: -170
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-324]
# Absolute error: -324
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-44]
# Absolute error: -44
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-112]
# Absolute error: -112
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-49]
# Absolute error: -49
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [174]
# Absolute error: 174
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [5]
# Absolute error: 5
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [211]
# Absolute error: 211
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [227]
# Absolute error: 227
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [121]
# Absolute error: 121
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-185]
# Absolute error: -185
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [199]
# Absolute error: 199
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [4]
# Absolute error: 4
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [160]
# Absolute error: 160
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-9]
# Absolute error: -9
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [169]
# Absolute error: 169
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-45]
# Absolute error: -45
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-163]
# Absolute error: -163
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [34]
# Absolute error: 34
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-278]
# Absolute error: -278
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-137]
# Absolute error: -137
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-125]
# Absolute error: -125
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 2 peaks, location: [-231 -207]
# Absolute error: -231
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-41]
# Absolute error: -41
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-39]
# Absolute error: -39
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-122]
# Absolute error: -122
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-314]
# Absolute error: -314
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-121]
# Absolute error: -121
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-247]
# Absolute error: -247
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-275]
# Absolute error: -275
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-52]
# Absolute error: -52
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-36]
# Absolute error: -36
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-36]
# Absolute error: -36
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [103]
# Absolute error: 103
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-73]
# Absolute error: -73
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-199]
# Absolute error: -199
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-73]
# Absolute error: -73
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [17]
# Absolute error: 17
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [165]
# Absolute error: 165
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-57]
# Absolute error: -57
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [25]
# Absolute error: 25
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-212]
# Absolute error: -212
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-114]
# Absolute error: -114
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [112]
# Absolute error: 112
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-152]
# Absolute error: -152
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-55]
# Absolute error: -55
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-95]
# Absolute error: -95
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-254]
# Absolute error: -254
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-276]
# Absolute error: -276
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [42]
# Absolute error: 42
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-24]
# Absolute error: -24
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-254]
# Absolute error: -254
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [60]
# Absolute error: 60
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-360]
# Absolute error: -360
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-231]
# Absolute error: -231
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [59]
# Absolute error: 59
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [254]
# Absolute error: 254
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [124]
# Absolute error: 124
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [192]
# Absolute error: 192
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [157]
# Absolute error: 157
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-116]
# Absolute error: -116
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [50]
# Absolute error: 50
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [211]
# Absolute error: 211
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [129]
# Absolute error: 129
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [49]
# Absolute error: 49
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [36]
# Absolute error: 36
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-229]
# Absolute error: -229
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-188]
# Absolute error: -188
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [10]
# Absolute error: 10
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-132]
# Absolute error: -132
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [127]
# Absolute error: 127
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [100]
# Absolute error: 100
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-157]
# Absolute error: -157
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [26]
# Absolute error: 26
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [73]
# Absolute error: 73
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-108]
# Absolute error: -108
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-6]
# Absolute error: -6
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-8]
# Absolute error: -8
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-199]
# Absolute error: -199
# Image shape: H:480, W:640, C:3
# Infrared process: H:480, W:640, C:1
# CutOut shape: H:480, W:200, C:1
# Length:200
# Image shape: H:480, W:640, C:3
# CutOut shape: H:480, W:200, C:3
# Length:200
# Shape of ir_result: (441, 1)
# Shape of rgb_result: (441, 1)
# Shape of fusion_result: (441, 1)
# 1 peaks, location: [-91]
# Absolute error: -91

# %%
x_axis = np.arange(1, len(ir_img_list)+1)
print("Mean MAE of ir-img: {}".format(err_ir_mul.mean()))
print("Mean MAE of rgb-img: {}".format(err_rgb_mul.mean()))
print("Mean MAE of fusion: {}".format(err_fusion_mul.mean()))

plt.figure(figsize = (16,6))

plt.plot(x_axis,err_ir_mul, '-g', marker = "1", markersize = 10, label = "error_ir")
plt.plot(x_axis,err_rgb_mul, '-b',marker = "2", markersize = 10, label = "error_rgb")
plt.plot(x_axis,err_fusion_mul, '-r', marker = "3", markersize = 10, label = "error_fusion")

plt.title("Multi-cutout in multi-image experiment")
plt.xlabel("Number of images")
plt.ylabel("MAE")
plt.legend()
plt.grid()
plt.xticks(x_axis)
plt.show()
# Out:
# Mean MAE of ir-img: 152.26666666666668
# Mean MAE of rgb-img: 147.8
# Mean MAE of fusion: 126.73333333333333
